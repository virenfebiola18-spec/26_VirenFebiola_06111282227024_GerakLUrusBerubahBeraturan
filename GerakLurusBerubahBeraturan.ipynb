# %% [markdown]
# Gerak lurus berubah beraturan (GLBB) adalah gerak benda pada lintasan lurus dengan
# **percepatan konstan**. Pada gerak ini, kecepatan benda tidak tetap, tetapi berubah secara
# beraturan setiap selang waktu tertentu. Perubahan kecepatan yang teratur ini disebabkan
# oleh percepatan \(a\), yang dapat bernilai positif (benda dipercepat) maupun negatif
# (benda diperlambat atau mengalami perlambatan).
#
# Berbeda dengan gerak lurus beraturan (GLB) yang memiliki kecepatan konstan, GLBB
# menunjukkan hubungan yang lebih dinamis antara posisi, kecepatan, dan percepatan.
# Perubahan kecepatan dan posisi dalam GLBB tidak dipengaruhi oleh gaya hambatan
# atau faktor eksternal lain, sehingga model matematisnya dapat dianalisis secara
# langsung menggunakan persamaan kinematika, tanpa memerlukan metode numerik.
#
# Model gerak pada GLBB didasarkan pada tiga persamaan dasar berikut:
#
# ### **1. Percepatan konstan**
# $$a = \frac{dv}{dt}$$
#
# ### **2. Hubungan kecepatan terhadap waktu**
# $$v(t) = v_0 + at$$
#
# ### **3. Perubahan posisi terhadap waktu**
# $$
# x(t) = x_0 + v_0 t + \frac{1}{2} a t^2$$
#
# Persamaan pertama menunjukkan bahwa percepatan adalah laju perubahan kecepatan
# terhadap waktu. Persamaan kedua menggambarkan bagaimana kecepatan meningkat atau
# menurun secara linear tergantung nilai percepatan. Persamaan ketiga menyatakan bahwa
# posisi benda berubah secara kuadratis terhadap waktu akibat adanya percepatan.
#
# Simulasi ini bertujuan untuk memodelkan bagaimana kecepatan dan posisi benda berubah
# dari waktu ke waktu ketika benda bergerak lurus dengan percepatan konstan. Dengan
# model ini, kita dapat menggambarkan grafik gerak, menghitung posisi dan kecepatan
# pada setiap waktu, serta memahami karakteristik dasar GLBB secara komputasional.

# %%
import numpy as np
import matplotlib.pyplot as plt


# Parameter GLBB
x0 = 0      # posisi awal (meter)
v0 = 5      # kecepatan awal (m/s)
a = 2       # percepatan (m/s^2)

t_akhir = 10   # durasi simulasi (detik)
dt = 0.1       # interval waktu

# Waktu
t = np.arange(0, t_akhir + dt, dt)

# Perhitungan GLBB
v = v0 + a * t
x = x0 + v0 * t + 0.5 * a * (t**2)

print("=== DATA SIMULASI GLBB ===")
for i in range(len(t)):
    print(f"t={t[i]:.1f} s  |  x={x[i]:.2f} m  |  v={v[i]:.2f} m/s")
plt.figure(figsize=(8,5))
plt.plot(t, x, label="Posisi (m)")

plt.title("Grafik Gerak Lurus Berubah Beraturan (GLBB)")
plt.xlabel("Waktu (s)")
plt.ylabel("Posisi (m)")
plt.grid(True)
plt.legend()
plt.show()
# Out:
# === DATA SIMULASI GLBB ===
# t=0.0 s  |  x=0.00 m  |  v=5.00 m/s
# t=0.1 s  |  x=0.51 m  |  v=5.20 m/s
# t=0.2 s  |  x=1.04 m  |  v=5.40 m/s
# t=0.3 s  |  x=1.59 m  |  v=5.60 m/s
# t=0.4 s  |  x=2.16 m  |  v=5.80 m/s
# t=0.5 s  |  x=2.75 m  |  v=6.00 m/s
# t=0.6 s  |  x=3.36 m  |  v=6.20 m/s
# t=0.7 s  |  x=3.99 m  |  v=6.40 m/s
# t=0.8 s  |  x=4.64 m  |  v=6.60 m/s
# t=0.9 s  |  x=5.31 m  |  v=6.80 m/s
# t=1.0 s  |  x=6.00 m  |  v=7.00 m/s
# t=1.1 s  |  x=6.71 m  |  v=7.20 m/s
# t=1.2 s  |  x=7.44 m  |  v=7.40 m/s
# t=1.3 s  |  x=8.19 m  |  v=7.60 m/s
# t=1.4 s  |  x=8.96 m  |  v=7.80 m/s
# t=1.5 s  |  x=9.75 m  |  v=8.00 m/s
# t=1.6 s  |  x=10.56 m  |  v=8.20 m/s
# t=1.7 s  |  x=11.39 m  |  v=8.40 m/s
# t=1.8 s  |  x=12.24 m  |  v=8.60 m/s
# t=1.9 s  |  x=13.11 m  |  v=8.80 m/s
# t=2.0 s  |  x=14.00 m  |  v=9.00 m/s
# t=2.1 s  |  x=14.91 m  |  v=9.20 m/s
# t=2.2 s  |  x=15.84 m  |  v=9.40 m/s
# t=2.3 s  |  x=16.79 m  |  v=9.60 m/s
# t=2.4 s  |  x=17.76 m  |  v=9.80 m/s
# t=2.5 s  |  x=18.75 m  |  v=10.00 m/s
# t=2.6 s  |  x=19.76 m  |  v=10.20 m/s
# t=2.7 s  |  x=20.79 m  |  v=10.40 m/s
# t=2.8 s  |  x=21.84 m  |  v=10.60 m/s
# t=2.9 s  |  x=22.91 m  |  v=10.80 m/s
# t=3.0 s  |  x=24.00 m  |  v=11.00 m/s
# t=3.1 s  |  x=25.11 m  |  v=11.20 m/s
# t=3.2 s  |  x=26.24 m  |  v=11.40 m/s
# t=3.3 s  |  x=27.39 m  |  v=11.60 m/s
# t=3.4 s  |  x=28.56 m  |  v=11.80 m/s
# t=3.5 s  |  x=29.75 m  |  v=12.00 m/s
# t=3.6 s  |  x=30.96 m  |  v=12.20 m/s
# t=3.7 s  |  x=32.19 m  |  v=12.40 m/s
# t=3.8 s  |  x=33.44 m  |  v=12.60 m/s
# t=3.9 s  |  x=34.71 m  |  v=12.80 m/s
# t=4.0 s  |  x=36.00 m  |  v=13.00 m/s
# t=4.1 s  |  x=37.31 m  |  v=13.20 m/s
# t=4.2 s  |  x=38.64 m  |  v=13.40 m/s
# t=4.3 s  |  x=39.99 m  |  v=13.60 m/s
# t=4.4 s  |  x=41.36 m  |  v=13.80 m/s
# t=4.5 s  |  x=42.75 m  |  v=14.00 m/s
# t=4.6 s  |  x=44.16 m  |  v=14.20 m/s
# t=4.7 s  |  x=45.59 m  |  v=14.40 m/s
# t=4.8 s  |  x=47.04 m  |  v=14.60 m/s
# t=4.9 s  |  x=48.51 m  |  v=14.80 m/s
# t=5.0 s  |  x=50.00 m  |  v=15.00 m/s
# t=5.1 s  |  x=51.51 m  |  v=15.20 m/s
# t=5.2 s  |  x=53.04 m  |  v=15.40 m/s
# t=5.3 s  |  x=54.59 m  |  v=15.60 m/s
# t=5.4 s  |  x=56.16 m  |  v=15.80 m/s
# t=5.5 s  |  x=57.75 m  |  v=16.00 m/s
# t=5.6 s  |  x=59.36 m  |  v=16.20 m/s
# t=5.7 s  |  x=60.99 m  |  v=16.40 m/s
# t=5.8 s  |  x=62.64 m  |  v=16.60 m/s
# t=5.9 s  |  x=64.31 m  |  v=16.80 m/s
# t=6.0 s  |  x=66.00 m  |  v=17.00 m/s
# t=6.1 s  |  x=67.71 m  |  v=17.20 m/s
# t=6.2 s  |  x=69.44 m  |  v=17.40 m/s
# t=6.3 s  |  x=71.19 m  |  v=17.60 m/s
# t=6.4 s  |  x=72.96 m  |  v=17.80 m/s
# t=6.5 s  |  x=74.75 m  |  v=18.00 m/s
# t=6.6 s  |  x=76.56 m  |  v=18.20 m/s
# t=6.7 s  |  x=78.39 m  |  v=18.40 m/s
# t=6.8 s  |  x=80.24 m  |  v=18.60 m/s
# t=6.9 s  |  x=82.11 m  |  v=18.80 m/s
# t=7.0 s  |  x=84.00 m  |  v=19.00 m/s
# t=7.1 s  |  x=85.91 m  |  v=19.20 m/s
# t=7.2 s  |  x=87.84 m  |  v=19.40 m/s
# t=7.3 s  |  x=89.79 m  |  v=19.60 m/s
# t=7.4 s  |  x=91.76 m  |  v=19.80 m/s
# t=7.5 s  |  x=93.75 m  |  v=20.00 m/s
# t=7.6 s  |  x=95.76 m  |  v=20.20 m/s
# t=7.7 s  |  x=97.79 m  |  v=20.40 m/s
# t=7.8 s  |  x=99.84 m  |  v=20.60 m/s
# t=7.9 s  |  x=101.91 m  |  v=20.80 m/s
# t=8.0 s  |  x=104.00 m  |  v=21.00 m/s
# t=8.1 s  |  x=106.11 m  |  v=21.20 m/s
# t=8.2 s  |  x=108.24 m  |  v=21.40 m/s
# t=8.3 s  |  x=110.39 m  |  v=21.60 m/s
# t=8.4 s  |  x=112.56 m  |  v=21.80 m/s
# t=8.5 s  |  x=114.75 m  |  v=22.00 m/s
# t=8.6 s  |  x=116.96 m  |  v=22.20 m/s
# t=8.7 s  |  x=119.19 m  |  v=22.40 m/s
# t=8.8 s  |  x=121.44 m  |  v=22.60 m/s
# t=8.9 s  |  x=123.71 m  |  v=22.80 m/s
# t=9.0 s  |  x=126.00 m  |  v=23.00 m/s
# t=9.1 s  |  x=128.31 m  |  v=23.20 m/s
# t=9.2 s  |  x=130.64 m  |  v=23.40 m/s
# t=9.3 s  |  x=132.99 m  |  v=23.60 m/s
# t=9.4 s  |  x=135.36 m  |  v=23.80 m/s
# t=9.5 s  |  x=137.75 m  |  v=24.00 m/s
# t=9.6 s  |  x=140.16 m  |  v=24.20 m/s
# t=9.7 s  |  x=142.59 m  |  v=24.40 m/s
# t=9.8 s  |  x=145.04 m  |  v=24.60 m/s
# t=9.9 s  |  x=147.51 m  |  v=24.80 m/s
# t=10.0 s  |  x=150.00 m  |  v=25.00 m/s

# %% [markdown]
# Grafik di atas menunjukkan bagaimana perubahan posisi benda terhadap waktu pada gerak lurus berubah beraturan. Pada percobaan ini, benda bergerak dengan percepatan tetap, sehingga grafik posisi yang dihasilkan tidak berbentuk garis lurus, tetapi melengkung ke atas.
#
# Rumus yang digunakan dalam GLBB adalah:
# $$s(t) = s_0 + v_0  t + (1/2) a  t^2$$
#
#
# Pada grafik dapat dilihat bahwa pada detik–detik awal, posisi benda bertambah masih sedikit karena kecepatannya juga masih kecil. Namun, semakin lama, grafik mulai terlihat naik lebih cepat, menandakan kecepatan benda terus bertambah akibat percepatan tetap yang diberikan.
#
# Mulai dari waktu 0,1 sampai 10 detik, posisi benda meningkat semakin cepat dan akhirnya mencapai sekitar 150 meter pada detik ke-10. Bentuk kurva yang menanjak ini menunjukkan bahwa gerak yang terjadi memang termasuk GLBB, karena perubahan posisinya dipengaruhi percepatan yang konstan.
#
# Secara keseluruhan, grafik ini memperlihatkan bahwa pada GLBB, semakin lama waktu bergerak, semakin besar jarak yang ditempuh, dan laju pertambahannya juga semakin cepat. Inilah ciri utama dari gerak lurus berubah beraturan.
